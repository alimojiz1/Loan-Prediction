# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("D:/Datasets/training_data.csv")

# %%
data.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP001002       1        0           0          0              0
# 1  LP001003       1        1           1          0              0
# 2  LP001005       1        1           0          0              1
# 3  LP001006       1        1           0          1              0
# 4  LP001008       1        0           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         120               360
# 1             4583             1508.0         128               360
# 2             3000                0.0          66               360
# 3             2583             2358.0         120               360
# 4             6000                0.0         141               360
#
#    Credit_History  Property_Area Loan_Status
# 0               1              2           Y
# 1               1              0           N
# 2               1              2           Y
# 3               1              2           Y
# 4               1              2           Y

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from tpot import TPOTClassifier
# Out:
# C:\Users\mojiza\AppData\Local\Continuum\anaconda2\envs\py36\lib\site-packages\deap\tools\_hypervolume\pyhv.py:33: ImportWarning: Falling back to the python version of hypervolume module. Expect this to be very slow.
#   "module. Expect this to be very slow.", ImportWarning)
# C:\Users\mojiza\AppData\Local\Continuum\anaconda2\envs\py36\lib\importlib\_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# C:\Users\mojiza\AppData\Local\Continuum\anaconda2\envs\py36\lib\importlib\_bootstrap_external.py:426: ImportWarning: Not importing directory c:\users\mojiza\appdata\local\continuum\anaconda2\envs\py36\lib\site-packages\mpl_toolkits: missing __init__
#   _warnings.warn(msg.format(portions[0]), ImportWarning)

# %%
y_train=data['Loan_Status']

# %%
X_train = data.drop(data.columns[[0,12]],axis=1,inplace=True)

# %%
X_train = data

# %%
tpot = TPOTClassifier(generations = 5, population_size = 20, verbosity =2)
tpot.fit(X_train,y_train)
tpot.export('tpot_mnist_pipeline.py')
# Out:
# C:\Users\mojiza\AppData\Local\Continuum\anaconda2\envs\py36\lib\importlib\_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# Warning: xgboost.XGBClassifier is not available and will not be used by TPOT.
# Generation 1 - Current best internal CV score: 0.8095716552088842
# Generation 2 - Current best internal CV score: 0.8095716552088842
# Generation 3 - Current best internal CV score: 0.8095716552088842
# Generation 4 - Current best internal CV score: 0.8095716552088842
# Generation 5 - Current best internal CV score: 0.8095716552088842
# Best pipeline: ExtraTreesClassifier(input_matrix, bootstrap=False, criterion=gini, max_features=0.8500000000000001, min_samples_leaf=18, min_samples_split=15, n_estimators=100)
# True

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
tpot_data = pd.read_csv('D:/Datasets/training_data.csv')
tpot_data.drop(tpot_data.columns[[0]],axis=1,inplace=True)
features = tpot_data.drop('Loan_Status', axis=1).values
training_features, testing_features, training_target, testing_target = \
            train_test_split(features, tpot_data['Loan_Status'].values, random_state=42)

# Score on the training set was:0.8095716552088842
exported_pipeline = ExtraTreesClassifier(bootstrap=False, criterion="gini", max_features=0.8500000000000001, min_samples_leaf=18, min_samples_split=15, n_estimators=100)

model=exported_pipeline.fit(training_features, training_target)

# %%
import pickle

# %%
list_pickle = pickle.dumps(model)

# %%
list_pickle
# Out:
# b'\x80\x03csklearn.ensemble.forest\nExtraTreesClassifier\nq\x00)\x81q\x01}q\x02(X\x0e\x00\x00\x00base_estimatorq\x03csklearn.tree.tree\nExtraTreeClassifier\nq\x04)\x81q\x05}q\x06(X\t\x00\x00\x00criterionq\x07X\x04\x00\x00\x00giniq\x08X\x08\x00\x00\x00splitterq\tX\x06\x00\x00\x00randomq\nX\t\x00\x00\x00max_depthq\x0bNX\x11\x00\x00\x00min_samples_splitq\x0cK\x02X\x10\x00\x00\x00min_samples_leafq\rK\x01X\x18\x00\x00\x00min_weight_fraction_leafq\x0eG\x00\x00\x00\x00\x00\x00\x00\x00X\x0c\x00\x00\x00max_featuresq\x0fX\x04\x00\x00\x00autoq\x10X\x0c\x00\x00\x00random_stateq\x11NX\x0e\x00\x00\x00max_leaf_nodesq\x12NX\x15\x00\x00\x00min_impurity_decreaseq\x13G\x00\x00\x00\x00\x00\x00\x00\x00X\x12\x00\x00\x00min_impurity_splitq\x14NX\x0c\x00\x00\x00class_weightq\x15NX\x07\x00\x00\x00presortq\x16\x89X\x10\x00\x00\x00_sklearn_versionq\x17X\x06\x00\x00\x000.19.1q\x18ubX\x0c\x00\x00\x00n_estimatorsq\x19KdX\x10\x00\x00\x00estimator_paramsq\x1a(h\x07h\x0bh\x0ch\rh\x0eh\x0fh\x12h\x13h\x14h\x11tq\x1bX\t\x00\x00\x00bootstrapq\x1c\x89X\t\x00\x00\x00oob_scoreq\x1d\x89X\x06\x00\x00\x00n_jobsq\x1eK\x01h\x11NX\x07\x00\x00\x00verboseq\x1fK\x00X\n\x00\x00\x00warm_startq \x89h\x15Nh\x07h\x08h\x0bNh\x0cK\x0fh\rK\x12h\x0eG\x00\x00\x00\x00\x00\x00\x00\x00h\x0fG?\xeb333334h\x12Nh\x13G\x00\x00\x00\x00\x00\x00\x00\x00h\x14NX\x0b\x00\x00\x00n_features_q!K\x0bX\n\x00\x00\x00n_outputs_q"K\x01X\x08\x00\x00\x00classes_q#cnumpy.core.multiarray\n_reconstruct\nq$cnumpy\nndarray\nq%K\x00\x85q&C\x01bq\'\x87q(Rq)(K\x01K\x02\x85q*cnumpy\ndtype\nq+X\x02\x00\x00\x00O8q,K\x00K\x01\x87q-Rq.(K\x03X\x01\x00\x00\x00|q/NNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK?tq0b\x89]q1(X\x01\x00\x00\x00Nq2X\x01\x00\x00\x00Yq3etq4bX\n\x00\x00\x00n_classes_q5K\x02X\x0f\x00\x00\x00base_estimator_q6h\x05X\x0b\x00\x00\x00estimators_q7]q8(h\x04)\x81q9}q:(h\x07h\x08h\th\nh\x0bNh\x0cK\x0fh\rK\x12h\x0eG\x00\x00\x00\x00\x00\x00\x00\x00h\x0fG?\xeb333334h\x11J\x16BD}h\x12Nh\x13G\x00\x00\x00\x00\x00\x00\x00\x00h\x14Nh\x15Nh\x16\x89h!K\x0bh"K\x01h#h$h%K\x00\x85q;h\'\x87q<Rq=(K\x01K\x02\x85q>h+X\x02\x00\x00\x00f8q?K\x00K\x01\x87q@RqA(K\x03X\x01\x00\x00\x00<qBNNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK\x00tqCb\x89C\x10\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf0?qDtqEbh5cnumpy.core.multiarray\nscalar\nqFh+X\x02\x00\x00\x00i8qGK\x00K\x01\x87qHRqI(K\x03hBNNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK\x00tqJbC\x08\x02\x00\x00\x00\x00\x00\x00\x00qK\x86qLRqMX\r\x00\x00\x00max_features_qNK\tX\x05\x00\x00\x00tree_qOcsklearn.tree._tree\nTree\nqPK\x0bh$h%K\x00\x85qQh\'\x87qRRqS(K\x01K\x01\x85qThI\x89C\x08\x02\x00\x00\x00\x00\x00\x00\x00qUtqVbK\x01\x87qWRqX}qY(h\x0bK\x08X\n\x00\x00\x00node_countqZK\x1fX\x05\x00\x00\x00nodesq[h$h%K\x00\x85q\\h\'\x87q]Rq^(K\x01K\x1f\x85q_h+X\x03\x00\x00\x00V56q`K\x00K\x01\x87qaRqb(K\x03h/N(X\n\x00\x00\x00left_childqcX\x0b\x00\x00\x00right_childqdX\x07\x00\x00\x00featureqeX\t\x00\x00\x00thresholdqfX\x08\x00\x00\x00impurityqgX\x0e\x00\x00\x00n_node_samplesqhX\x17\x00\x00\x00weighted_n_node_samplesqitqj}qk(hchIK\x00\x86qlhdhIK\x08\x86qmhehIK\x10\x86qnhfhAK\x18\x86qohghAK \x86qphhhIK(\x86qqhihAK0\x86qruK8K\x01K\x10tqsb\x89B\xc8\x06\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\x00\x00\x00\x00\t\x00\x00\x00\x00\x00\x00\x00P\xc4\xb3\xf9\'\xe2\xe9?\xe2z\x14\xaeG\xe1\xda?\xcc\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xc0|@\x02\x00\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\xb8+) \xdc\x95\xc4?\xccU\xd3=\xb9\xec\xc1?B\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x80P@\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xfe\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x00\x00\x00\x00\xc0\xc8\xb5HPS!\xca?\x1a\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00:@\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xfe\xff\xff\xff\xff\xff\xff\xff\x00\x00\x00\x00\x00\x00\x00\xc0P\xb8\x1e\x85\xebQ\xb8?(\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00D@\x05\x00\x00\x00\x00\x00\x00\x00\x0e\x00\x00\x00\x00\x00\x00\x00\x0 ...

# %%
loaded_pickle = pickle.loads(list_pickle)

# %%
loaded_pickle
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features=0.8500000000000001,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=18,
#            min_samples_split=15, min_weight_fraction_leaf=0.0,
#            n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
import dill as pickle

# %%
filename='model_v1.pk'

# %%
with open('D:/Flask_API/Models/'+filename,'wb') as file:
    pickle.dump(model,file)

# %%
with open('D:/Flask_API/Models/'+filename ,'rb') as f:
    loaded_model = pickle.load(f)

# %%
test_data=pd.read_csv("D:/Datasets/loan_test.csv")

# %%
loaded_model.predict(test_data)
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y'], dtype=object)
